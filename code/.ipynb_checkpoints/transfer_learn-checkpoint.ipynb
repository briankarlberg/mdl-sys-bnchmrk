# %% [markdown]
# # R72

# %%
# R72:
    # cell line -> CPTAC, 5 cancer types
    # HCMI -> CPTAC, 2 cancer types

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
# Data handling & comparision setup
import pandas as pd
import glob
import itertools

# Feature selection, RFE
from sklearn.feature_selection import RFE
from sklearn.svm import SVR

# Import 3 SciKit Learn classifiers
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.linear_model import LogisticRegression

# SVM
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# Classification setup and eval
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import statistics

# Plotting
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set data paths

# %% [markdown]
# #### Input read

# %%
# phase = 'Input'
inp_pths = sorted(
    glob.glob('../data/r72/*.tsv'), reverse = True)
inp_pths
# Out:
# ['../data/r72/nc5_transcriptomics_cell-line+CPTAC.tsv',
#  '../data/r72/nc2_transcriptomics_HCMI+CPTAC.tsv']

# %% [markdown]
# ##### Check label capitalization on input paths

# %%
for inp_pth in inp_pths:
    df = pd.read_csv(
        inp_pth, sep = '\t', index_col = 0)
    print(df.System.unique())

# %%
# Conclusion - MBatch rebuild script converted to caps
    # archive caps versions
    # conver to lowercase and re-write

# %% [markdown]
# #### MBatch

# %%
# phase = 'MBatch'
mb_pths = sorted(
    glob.glob('../results/r72/mbatch/*.tsv'), reverse = True)
mb_pths
# Out:
# ['../results/r72/mbatch/nc5_transcriptomics_cell-line+CPTAC.tsv',
#  '../results/r72/mbatch/nc2_transcriptomics_HCMI+CPTAC.tsv']

# %% [markdown]
# ##### MBatch i-o de-capitilize

# %%
for mb_pth in mb_pths:
    df = pd.read_csv(
        mb_pth, sep = '\t', index_col = 0)
    print(df.System.unique())

# %%
mb_pths = sorted(
    glob.glob('../results/r72/mbatch/cap_lbls_archive/*.tsv'), reverse = True)
for mb_pth in mb_pths:
    # print(mb_pth)
    f_nm = mb_pth.split('/')[-1]
    df = pd.read_csv(
        mb_pth, sep = '\t', index_col = 0)
    print(df.System.unique())

    df['System'] = df['System'].str.lower()
    
    print(df.System.unique())

    df.to_csv(
        '../results/r72/mbatch/'+f_nm,
        sep = '\t')
    print(' ')
    # break

# %%
f_nm = mb_pth.split('/')[-1]

# %%
f_nm

# %% [markdown]
# #### VAE

# %%
ls ../results/r72/vae/

# %%
# phase = 'VAE'
vae_pths = sorted(
    glob.glob('../results/r72/vae/*.tsv'), reverse = True)
vae_pths
# Out:
# ['../results/r72/vae/nc5_transcriptomics_cell-line+CPTAC_latent_space.tsv',
#  '../results/r72/vae/nc2_transcriptomics_hcmi+CPTAC_latent_space.tsv']

# %% [markdown]
# #### Tybalt

# %%
ls ../results/r72/tybalt/

# %%
tb_pths = sorted(
    glob.glob('../results/r72/tybalt/*.tsv'), reverse = True)
tb_pths
# Out:
# ['../results/r72/tybalt/nc5_transcriptomics_cell-line+CPTAC.250-ltnt-dim_12-epchs.tsv',
#  '../results/r72/tybalt/nc2_transcriptomics_HCMI+CPTAC.250-ltnt-dim_12-epchs.tsv']

# %%
# skip RFE for now, start with 3 clf on raw and mbatch

# %% [markdown]
# ### RFE

# %%
for pth in inp:
    df = pd.read_csv(
        pth, sep = '\t', index_col = 0)
    X = df.iloc[:, 2:]
    break

# %%
df

# %%
estimator = SVR(kernel="linear")
rfe = RFE(estimator=estimator, n_features_to_select=10, step=0.5)
file_n = pd.read_csv(pth, sep = '\t', index_col = 0) # read validation split file
X = file_n.iloc[:, 1:]
y = file_n.iloc[:, 0]
rfe.fit(X, y)
mask = rfe.support_
vs_dict[vs] = json.dumps(list(X.columns[mask]))

# %% [markdown]
# ### Subsample cross val devel

# %%
# Sub-sample input at 80%
# match row index on corr df

# %%
inp_pths

# %%
tb_pths

# %%
vae_pths

# %%
# Questions - sub-sample on only the input?
# Predict on entire CPTAC?

# split before subsample? - yes, that's what X was

# %% [markdown]
# ### Load data

# %%
path_index_toggle = 0
cancer_count = 5
sys_togg = 'cell-line'
sys_file_names = 'cell-line+CPTAC'
sample_count_lbl = 'Cell line'
mdl_sys_inline = 'cell line'

# %%
path_index_toggle = 1
cancer_count = 2
sys_togg = 'hcmi'
sys_file_names = 'HMCI+CPTAC'
sample_count_lbl = 'HCMI'
mdl_sys_inline = 'HCMI'

# %%
path_index_toggle
# Out:
# 1

# %%
inp_pths
# Out:
# ['../data/r72/nc5_transcriptomics_cell-line+CPTAC.tsv',
#  '../data/r72/nc2_transcriptomics_HCMI+CPTAC.tsv']

# %%
# Input load
input_df = pd.read_csv(
                inp_pths[path_index_toggle], # nc5 or nc2 file
                sep = '\t',
                index_col = 0)
print('inpt len:', len(input_df))
# Out:
# inpt len: 332

# %%
# MBatch load
corr_df = pd.read_csv(
                mb_pths[path_index_toggle],
                sep = '\t',
                index_col = 0)
corr_pths = mb_pths
print('MB corr len:', len(corr_df))
corr_mthd_title = 'MBatch'
mthd_file_disk_name = 'mbatch'
latent_dim = 'NA'
# Out:
# MB corr len: 332

# %%
# VAE load
corr_df = pd.read_csv(
        vae_pths[path_index_toggle],
        sep = '\t',
        index_col = 0)
corr_pths = vae_pths
print('vae latent len:', len(corr_df))
corr_mthd_title = 'VAE_n'
mthd_file_disk_name = 'vae_n'
latent_dim = 50
# Out:
# vae latent len: 332

# %%
# Tybalt load
corr_df = pd.read_csv(
            tb_pths[path_index_toggle],
            sep = '\t',
            index_col = 0)
print('Tybalt latent len:', len(corr_df))
corr_mthd_title = 'Tybalt baseline VAE'
mthd_file_disk_name = 'tybalt'
# Out:
# Tybalt latent len: 332

# %%
# Cellinger

# %% [markdown]
# ### Clf

# %%
# print('Begin clf on ', phase)
print('Begin sub-sampled, matched-cross val\n classification evals')
print(' ')
print('Input file:\n', inp_pths[path_index_toggle].split('/')[-1])
print('Correction file:\n', corr_pths[path_index_toggle].split('/')[-1])
print(' ')

clf_list = [RandomForestClassifier(max_depth=2, random_state=0),
            tree.DecisionTreeClassifier(),
            LogisticRegression(random_state=0, max_iter=5000),
            make_pipeline(StandardScaler(),
                LinearSVC(dual="auto", random_state=0,
                          max_iter=100000, tol=1e-5))]

# Subset training input
# inp_mdl_sys_train_df = input_df[input_df.System == 'cell-line']

# Subset correction object, toggle with file read
# corr_mdl_sys_train_df = corr_df[corr_df.System == 'cell-line']

if path_index_toggle == 1:
# HCMI
# Subset training input
    inp_mdl_sys_train_df = input_df[input_df.System == sys_togg]

# Subset correction object, toggle with file read
    corr_mdl_sys_train_df = corr_df[corr_df.System == sys_togg]
else:
    print('cell-line')
    print(sys_togg)
    inp_mdl_sys_train_df = input_df[input_df.System == sys_togg]
    corr_mdl_sys_train_df = corr_df[corr_df.System == sys_togg]
# List of dicts
results = []

for cross_val in range(30): # chk
    print('cross_val', cross_val)

    # Train set sub-sample, input - X and y
    X_input = inp_mdl_sys_train_df.iloc[:, 2:]
    X_input = X_input.sample(round(len(X_input)*.85))
    y_input = inp_mdl_sys_train_df[inp_mdl_sys_train_df.index.isin(
                                        X_input.index)].Cancer_type

    # Train set sub-sample, corr - X and y
    X_corr = corr_mdl_sys_train_df.iloc[:, 2:]
    X_corr = X_corr[X_corr.index.isin(X_input.index)]
    y_corr = corr_mdl_sys_train_df[corr_mdl_sys_train_df.index.isin(
                                        X_corr.index)].Cancer_type

    # Test set extraction, input and corr
    CPTAC_input = input_df[input_df.System == 'cptac']
    CPTAC_corr = corr_df[corr_df.System == 'cptac']

    # print(len(CPTAC_input))
    # print(len(CPTAC_corr))
    
    clf_i_list = ['RF', 'DT', 'LR', 'SVM']

    # Classifier loop, input
    print('Start input loop')
    input_score_list = []
    for clf_i in range(len(clf_list)):
        clf = clf_list[clf_i]
        clf.fit(X_input,
                y_input)
    
        score = f1_score(CPTAC_input.Cancer_type,
                         clf.predict(CPTAC_input.iloc[:, 2:]),
                         average = 'weighted')
        
        results.append({
            'cross_val': cross_val,
            'classifier': clf_i_list[clf_i],
            'score': score,
            'type': 'input'
        })
        # break
    # Classifier loop, correction method
    print('Start correction eval loop')
    for clf_i in range(len(clf_list)):
        clf = clf_list[clf_i]
        clf.fit(X_corr,
                y_corr)
    
        score = f1_score(CPTAC_corr.Cancer_type,
                         clf.predict(CPTAC_corr.iloc[:, 2:]),
                         average = 'weighted')
        results.append({
            'cross_val': cross_val,
            'classifier': clf_i_list[clf_i],
            'score': score,
            'type': 'corrected'
        })

    # print('end cross fold')
    print(' ')
    # break
print('done')
# Out:
# Begin sub-sampled, matched-cross val
#  classification evals
#
# Input file:
#  nc2_transcriptomics_HCMI+CPTAC.tsv
# Correction file:
#  nc2_transcriptomics_hcmi+CPTAC_latent_space.tsv
#
# cross_val 0
# Start input loop
# Start correction eval loop
#
# cross_val 1
# Start input loop
# Start correction eval loop
#
# cross_val 2
# Start input loop
# Start correction eval loop
#
# cross_val 3
# Start input loop
# Start correction eval loop
#
# cross_val 4
# Start input loop
# Start correction eval loop
#
# cross_val 5
# Start input loop
# Start correction eval loop
#
# cross_val 6
# Start input loop
# Start correction eval loop
#
# cross_val 7
# Start input loop
# Start correction eval loop
#
# cross_val 8
# Start input loop
# Start correction eval loop
#
# cross_val 9
# Start input loop
# Start correction eval loop
#
# cross_val 10
# Start input loop
# Start correction eval loop
#
# cross_val 11
# Start input loop
# Start correction eval loop
#
# cross_val 12
# Start input loop
# Start correction eval loop
#
# cross_val 13
# Start input loop
# Start correction eval loop
#
# cross_val 14
# Start input loop
# Start correction eval loop
#
# cross_val 15
# Start input loop
# Start correction eval loop
#
# cross_val 16
# Start input loop
# Start correction eval loop
#
# cross_val 17
# Start input loop
# Start correction eval loop
#
# cross_val 18
# Start input loop
# Start correction eval loop
#
# cross_val 19
# Start input loop
# Start correction eval loop
#
# cross_val 20
# Start input loop
# Start correction eval loop
#
# cross_val 21
# Start input loop
# Start correction eval loop
#
# cross_val 22
# Start input loop
# Start correction eval loop
#
# cross_val 23
# Start input loop
# Start correction eval loop
#
# cross_val 24
# Start input loop
# Start correction eval loop
#
# cross_val 25
# Start input loop
# Start correction eval loop
#
# cross_val 26
# Start input loop
# Start correction eval loop
#
# cross_val 27
# Start input loop
# Start correction eval loop
#
# cross_val 28
# Start input loop
# Start correction eval loop
#
# cross_val 29
# Start input loop
# Start correction eval loop
#
# done

# %%
results_df = pd.DataFrame(results)
# results_df

# %%
pd.options.display.max_rows = 300

# %%
results_df
# Out:
#      cross_val classifier     score       type
# 0            0         RF  0.257143      input
# 1            0         DT  0.257143      input
# 2            0         LR  0.257143      input
# 3            0        SVM  0.415584      input
# 4            0         RF  0.590476  corrected
# 5            0         DT  0.524332  corrected
# 6            0         LR  0.589380  corrected
# 7            0        SVM  0.573487  corrected
# 8            1         RF  0.255171      input
# 9            1         DT  0.501201      input
# 10           1         LR  0.257143      input
# 11           1        SVM  0.013825      input
# 12           1         RF  0.606027  corrected
# 13           1         DT  0.556231  corrected
# 14           1         LR  0.622231  corrected
# 15           1        SVM  0.601974  corrected
# 16           2         RF  0.415584      input
# 17           2         DT  0.415584      input
# 18           2         LR  0.415584      input
# 19           2        SVM  0.253695      input
# 20           2         RF  0.565463  corrected
# 21           2         DT  0.561395  corrected
# 22           2         LR  0.554236  corrected
# 23           2        SVM  0.539946  corrected
# 24           3         RF  0.257143      input
# 25           3         DT  0.257143      input
# 26           3         LR  0.257143      input
# 27           3        SVM  0.257143      input
# 28           3         RF  0.447243  corrected
# 29           3         DT  0.520835  corrected
# 30           3         LR  0.535857  corrected
# 31           3        SVM  0.512621  corrected
# 32           4         RF  0.468496      input
# 33           4         DT  0.656909      input
# 34           4         LR  0.253695      input
# 35           4        SVM  0.415584      input
# 36           4         RF  0.391591  corrected
# 37           4         DT  0.463599  corrected
# 38           4         LR  0.545041  corrected
# 39           4        SVM  0.516775  corrected
# 40           5         RF  0.257143      input
# 41           5         DT  0.198579      input
# 42           5         LR  0.415584      input
# 43           5        SVM  0.257143      input
# 44           5         RF  0.513561  corrected
# 45           5         DT  0.541096  corrected
# 46           5         LR  0.569563  corrected
# 47           5        SVM  0.537077  corrected
# 48           6         RF  0.415584      input
# 49           6         DT  0.412793      input
# 50           6         LR  0.251956      input
# 51           6        SVM  0.415584      input
# 52           6         RF  0.548054  corrected
# 53           6         DT  0.524332  corrected
# 54           6         LR  0.569354  corrected
# 55           6        SVM  0.542857  corrected
# 56           7         RF  0.257143      input
# 57           7         DT  0.637234      input
# 58           7         LR  0.415584      input
# 59           7        SVM  0.415584      input
# 60           7         RF  0.589829  corrected
# 61           7         DT  0.475211  corrected
# 62           7         LR  0.593037  corrected
# 63           7        SVM  0.553103  corrected
# 64           8         RF  0.415584      input
# 65           8         DT  0.257143      input
# 66           8         LR  0.257143      input
# 67           8        SVM  0.415584      input
# 68           8         RF  0.577640  corrected
# 69           8         DT  0.514566  corrected
# 70           8         LR  0.602726  corrected
# 71           8        SVM  0.568923  corrected
# 72           9         RF  0.236859      input
# 73           9         DT  0.257143      input
# 74           9         LR  0.257143      input
# 75           9        SVM  0.975445      input
# 76           9         RF  0.521558  corrected
# 77           9         DT  0.528867  corrected
# 78           9         LR  0.559184  corrected
# 79           9        SVM  0.555359  corrected
# 80          10         RF  0.415584      input
# 81          10         DT  0.117706      input
# 82          10         LR  0.257143      input
# 83          10        SVM  0.237674      input
# 84          10         RF  0.458248  corrected
# 85          10         DT  0.540991  corrected
# 86          10         LR  0.589735  corrected
# 87          10        SVM  0.605643  corrected
# 88          11         RF  0.284021      input
# 89          11         DT  0.246678      input
# 90          11         LR  0.257143      input
# 91          11        SVM  0.257143      input
# 92          11         RF  0.577297  corrected
# 93          11         DT  0.533000  corrected
# 94          11         LR  0.596944  corrected
# 95          11        SVM  0.567347  corrected
# 96          12         RF  0.415584      input
# 97          12         DT  0.429851      input
# 98          12         LR  0.257143      input
# 99          12        SVM  0.779491      input
# 100         12         RF  0.621664  corrected
# 101         12         DT  0.467771  corrected
# 102         12         LR  0.573487  corrected
# 103         12        SVM  0.508654  corrected
# 104         13         RF  0.642943      input
# 105         13         DT  0.415584      input
# 106         13         LR  0.415584      input
# 107         13        SVM  0.415584      input
# 108         13         RF  0.607419  corrected
# 109         13         DT  0.524332  corrected
# 110         13         LR  0.600840  corrected
# 111         13        SVM  0.579835  corrected
# 112         14         RF  0.257143      input
# 113         14         DT  0.415584      input
# 114         14         LR  0.415584      input
# 115         14        SVM  0.415584      input
# 116         14         RF  0.544351  corrected
# 117         14         DT  0.491414  corrected
# 118         14         LR  0.543817  corrected
# 119         14        SVM  0.528255  corrected
# 120         15         RF  0.304089      input
# 121         15         DT  0.255424      input
# 122         15         LR  0.415584      input
# 123         15        SVM  0.365079      input
# 124         15         RF  0.583424  corrected
# 125         15         DT  0.463927  corrected
# 126         15         LR  0.540824  corrected
# 127         15        SVM  0.528523  corrected
# 128         16         RF  0.257143      input
# 129         16         DT  0.415584      input
# 130         16         LR  0.415584      input
# 131         16        SVM  0.257143      input
# 132         16         RF  0.490600  corrected
# 133         16         DT  0.539283  corrected
# 134         16         LR  0.573625  corrected
# 135         16        SVM  0.528379  corrected
# 136         17         RF  0.255424      input
# 137         17         DT  0.195707      input
# 138         17         LR  0.257143      input
# 139         17        SVM  0.257143      input
# 140         17         RF  0.402244  corrected
# 141         17         DT  0.531620  corrected
# 142         17         LR  0.577640  corrected
# 143         17        SVM  0.553308  corrected
# 144         18         RF  0.560480      input
# 145         18         DT  0.540338      input
# 146         18         LR  0.415584      input
# 147         18        SVM  0.519112      input
# 148         18         RF  0.574975  corrected
# 149         18         DT  0.537077  corrected
# 150         18         LR  0.565463  corrected
# 151         18        SVM  0.532697  corrected
# 152         19         RF  0.257143      input
# 153         19         DT  0.449385      input
# 154         19         LR  0.257143      input
# 155         19        SVM  0.415584      input
# 156         19         RF  0.560944  corrected
# 157         19         DT  0.572126  corrected
# 158         19         LR  0.561290  corrected
# 159         19        SVM  0.561430  corrected
# 160         20         RF  0.528355      input
# 161         20         DT  0.995916      input
# 162         20         LR  0.257143      input
# 163         20        SVM  0.257143      input
# 164         20         RF  0.584339  corrected
# 165         20         DT  0.508399  corrected
# 166         20         LR  0.553236  corrected
# 167         20        SVM  0.520394  corrected
# 168         21         RF  0.311280      input
# 169         21         DT  0.415584      input
# 170         21         LR  0.257143      input
# 171         21        SVM  0.415584      input
# 172         21         RF  0.602038  corrected
# 173         21         DT  0.565504  corrected
# 174         21         LR  0.547676  corrected
# 175         21        SVM  0.510753  corrected
# 176         22         RF  0.608064      input
# 177         22         DT  0.744402      input
# 178         22         LR  0.415584      input
# 179         22        SVM  0.415584      input
# 180         22         RF  0.548054  corrected
# 181         22         DT  0.557382  corrected
# 182         22         LR  0.565205  corrected
# 183         22        SVM  0.544978  corrected
# 184         23         RF  0.903912      input
# 185         23         DT  0.257143      input
# 186         23         LR  0.257143      input
# 187         23        SVM  0.415584      input
# 188         23         RF  0.565726  corrected
# 189         23         DT  0.523226  corrected
# 190         23         LR  0.552773  corrected
# 191         23        SVM  0.549115  corrected
# 192         24         RF  0.208995      input
# 193         24         DT  0.415584      input
# 194         24         LR  0.415584      input
# 195         24        SVM  0.415584      input
# 196         24         RF  0.556286  corrected
# 197         24         DT  0.524570  corrected
# 198         24         LR  0.575986  corrected
# 199         24        SVM  0.566193  corrected
# 200         25         RF  0.879807      input
# 201         25         DT  0.415584      input
# 202         25         LR  0.415584      input
# 203         25        SVM  0.511540      input
# 204         25         RF  0.537131  corrected
# 205         25         DT  0.526247  corrected
# 206         25         LR  0.552999  corrected
# 207         25        SVM  0.528943  corrected
# 208         26         RF  0.442658      input
# 209         26         DT  0.540816      input
# 210         26         LR  0.257143      input
# 211         26        SVM  0.415584      input
# 212         26         RF  0.508811  corrected
# 213         26         DT  0.520394  corrected
# 214         26         LR  0.561442  corrected
# 215         26        SVM  0.508495  corrected
# 216         27         RF  0.415584      input
# 217         27         DT  0.135669      input
# 218         27         LR  0.257143      input
# 219         27        SVM  0.257143      input
# 220         27         RF  0.606242  corrected
# 221         27         DT  0.516524  corrected
# 222         27         LR  0.612876  corrected
# 223         27        SVM  0.568255  corrected
# 224         28         RF  0.676229      input
# 225         28         DT  0.294372      input
# 226         28         LR  0.415584      input
# 227         28        SVM  0.221805      input
# 228         28         RF  0.605840  corrected
# 229         28         DT  0.543817  corrected
# 230         28         LR  0.556574  corrected
# 231         28        SVM  0.544522  corrected
# 232         29         RF  0.257143      input
# 233         29         DT  0.450554      input
# 234         29         LR  0.232143      input
# 235         29        SVM  0.462571      input
# 236         29         RF  0.645103  corrected
# 237         29         DT  0.563126  corrected
# 238         29         LR  0.576401  corrected
# 239         29        SVM  0.503086  corrected

# %%
print(sys_file_names)
print(mthd_file_disk_name)
# Out:
# HMCI+CPTAC
# vae_n

# %%
results_df.to_csv('../results/r72/input-'+mthd_file_disk_name+'_transfer-lrn_x-val=30_'+sys_file_names+'.tsv',
                 sep = '\t')

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a figure and axis
plt.figure(figsize=(10, 7))

# Plot
sns.boxplot(data=results_df, x='classifier', y='score',
            hue='type', palette='Set2')

# cancer_count = 5
# cancer_count = 5

# Adding title and labels
plt.title('Transfer Learning Prediction Performance on Input'+
          ' vs Corrected Data\nTrain on '+mdl_sys_inline+' 85% subsample, '+
          'predict on CPTAC, n cancers = '+str(cancer_count)+
          '\n'+corr_mthd_title, fontsize=16)
plt.xlabel('Classifier', fontsize=15)
plt.ylabel('F1 Score', fontsize=15)
plt.legend(title='Data Type', fontsize=12)

plt.annotate(sample_count_lbl+' samples: {}'.format(len(X_input))+
             '\nCPTAC samples: {}'.format(len(CPTAC_corr))+
             '\nLatent dim: '+str(latent_dim)+'\nFeature count: {}'.format(
                 len(X_input.columns)), 
                 # xy=(0.03, 0.85), # Tybalt
                 xy=(0.55, 0.85),
                 xycoords='axes fraction', 
                 bbox=dict(boxstyle='round, pad=0.5', fc='white', ec='black'),
                 fontsize=12)

# Display the plot
plt.tight_layout()
plt.savefig('../results/r72/input-'+mthd_file_disk_name+'_transfer-lrn_x-val=30_'+sys_file_names+'.png',
            dpi = 300)
# plt.show()

# %%
X_input
