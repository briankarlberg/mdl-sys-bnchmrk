# %% [markdown]
# # R72

# %%
# R72: (second pass)
    # cell line -> CPTAC, 5 cancer types
    # HCMI -> CPTAC, 2 cancer types
# methods to bar plot test for r8

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
production_date = '2024-03-19'

# %%
# Data handling & comparision setup
import pandas as pd
import glob
import itertools

# Feature selection, RFE
from sklearn.feature_selection import RFE
from sklearn.svm import SVR

# Import 3 SciKit Learn classifiers
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.linear_model import LogisticRegression

# SVM
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# Classification setup and eval
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import statistics

# Plotting
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set data paths

# %% [markdown]
# #### Input read

# %%
# phase = 'Input', need for all comparisons
inp_pths = sorted(
    glob.glob('../data/r72/*.tsv'), reverse = True)
inp_pths
# Out:
# ['../data/r72/nc5_transcriptomics_cell-line+CPTAC.input-data.tsv',
#  '../data/r72/nc2_transcriptomics_HCMI+CPTAC.input-data.tsv']

# %% [markdown]
# ##### Check label capitalization on input paths

# %%
for inp_pth in inp_pths:
    df = pd.read_csv(
        inp_pth, sep = '\t', index_col = 0)
    print(df.System.unique())

# %%
# Conclusion - MBatch rebuild script converted to caps
    # archive caps versions
    # conver to lowercase and re-write

# %% [markdown]
# #### MBatch

# %%
# phase = 'MBatch'
mb_pths = sorted(
    glob.glob('../results/r72/mbatch/*.tsv'), reverse = True)
mb_pths
# Out:
# ['../results/r72/mbatch/nc5_transcriptomics_cell-line+CPTAC.mbatch.tsv',
#  '../results/r72/mbatch/nc2_transcriptomics_HCMI+CPTAC.mbatch.tsv']

# %% [markdown]
# ##### MBatch i-o de-capitilize

# %%
for mb_pth in mb_pths:
    df = pd.read_csv(
        mb_pth, sep = '\t', index_col = 0)
    print(df.System.unique())

# %%
mb_pths = sorted(
    glob.glob('../results/r72/mbatch/cap_lbls_archive/*.tsv'), reverse = True)
for mb_pth in mb_pths:
    # print(mb_pth)
    f_nm = mb_pth.split('/')[-1]
    df = pd.read_csv(
        mb_pth, sep = '\t', index_col = 0)
    print(df.System.unique())

    df['System'] = df['System'].str.lower()
    
    print(df.System.unique())

    df.to_csv(
        '../results/r72/mbatch/'+f_nm,
        sep = '\t')
    print(' ')
    # break

# %%
f_nm = mb_pth.split('/')[-1]

# %%
f_nm

# %% [markdown]
# #### Qaunt rescale

# %%
qs_pths = sorted(
    glob.glob('../results/r72/quant-resc/*.tsv'), reverse = True)
qs_pths
# Out:
# ['../results/r72/quant-resc/nc5_transcriptomics_cell-line+CPTAC.quant_resc.tsv',
#  '../results/r72/quant-resc/nc2_transcriptomics_HCMI+CPTAC.quant_resc.tsv']

# %% [markdown]
# #### VAE

# %%
ls ../results/r72/vae/
# Out:
# archive/
# beta-classifier/
# classifier/
# con_loss/
# disc/
# nc2_transcriptomics_hcmi+CPTAC_latent_space.tsv
# nc5_transcriptomics_cell-line+CPTAC_latent_space.tsv

# %%
ls ../results/r72/vae/beta-classifier/
# Out:
# archive_2024-03-19/
# nc2_transcriptomics_HCMI+CPTAC.beta-classifier_50-ltnt-dim_50-epchs.tsv
# nc5_transcriptomics_cell-line+CPTAC.beta-classifier_50-ltnt-dim_50-epchs.tsv

# %%
# phase = 'VAE beta-classifier'
vae_pths = sorted(
    glob.glob('../results/r72/vae/beta-classifier/*.tsv'), reverse = True)
vae_pths
# Out:
# ['../results/r72/vae/beta-classifier/nc5_transcriptomics_cell-line+CPTAC.beta-classifier_50-ltnt-dim_50-epchs.tsv',
#  '../results/r72/vae/beta-classifier/nc2_transcriptomics_HCMI+CPTAC.beta-classifier_50-ltnt-dim_50-epchs.tsv']

# %%
ls ../results/r72/vae/classifier/

# %%
# phase = 'VAE classifier'
vae_pths = sorted(
    glob.glob('../results/r72/vae/classifier/*.tsv'), reverse = True)
vae_pths
# Out:
# ['../results/r72/vae/classifier/nc5_transcriptomics_cell-line+CPTAC.classifier_50-ltnt-dim_100-epchs.tsv',
#  '../results/r72/vae/classifier/nc2_transcriptomics_HCMI+CPTAC.classifier_50-ltnt-dim_100-epchs.tsv']

# %%
ls ../results/r72/vae/con_loss/

# %%
# phase = 'VAE con_loss'
vae_pths = sorted(
    glob.glob('../results/r72/vae/con_loss/*.tsv'), reverse = True)
vae_pths

# %%
ls ../results/r72/vae/disc/

# %%
# phase = 'VAE disc'
vae_pths = sorted(
    glob.glob('../results/r72/vae/disc/*.tsv'), reverse = True)
vae_pths

# %% [markdown]
# #### Tybalt

# %%
ls ../results/r72/tybalt/

# %%
tb_pths = sorted(
    glob.glob('../results/r72/tybalt/*.tsv'), reverse = True)
tb_pths

# %%
# skip RFE for now, start with 3 clf on raw and mbatch

# %% [markdown]
# ### RFE

# %%
for pth in inp:
    df = pd.read_csv(
        pth, sep = '\t', index_col = 0)
    X = df.iloc[:, 2:]
    break

# %%
df

# %%
estimator = SVR(kernel="linear")
rfe = RFE(estimator=estimator, n_features_to_select=10, step=0.5)
file_n = pd.read_csv(pth, sep = '\t', index_col = 0) # read validation split file
X = file_n.iloc[:, 1:]
y = file_n.iloc[:, 0]
rfe.fit(X, y)
mask = rfe.support_
vs_dict[vs] = json.dumps(list(X.columns[mask]))

# %% [markdown]
# ### Subsample cross val devel

# %%
# Sub-sample input at 80%
# match row index on corr df

# %%
inp_pths

# %%
tb_pths

# %%
vae_pths

# %%
# Questions - sub-sample on only the input?
# Predict on entire CPTAC?

# split before subsample? - yes, that's what X was

# %% [markdown]
# ### Load data

# %%
path_index_toggle = 0
cancer_count = 5
sys_togg = 'cell-line'
sys_file_names = 'cell-line+CPTAC'
sample_count_lbl = 'Cell line'
mdl_sys_inline = 'cell line'

# %%
path_index_toggle = 1
cancer_count = 2
sys_togg = 'hcmi'
sys_file_names = 'HMCI+CPTAC'
sample_count_lbl = 'HCMI'
mdl_sys_inline = 'HCMI'

# %%
path_index_toggle
# Out:
# 0

# %%
inp_pths
# Out:
# ['../data/r72/nc5_transcriptomics_cell-line+CPTAC.input-data.tsv',
#  '../data/r72/nc2_transcriptomics_HCMI+CPTAC.input-data.tsv']

# %%
# Input load
input_df = pd.read_csv(
                inp_pths[path_index_toggle], # nc5 or nc2 file
                sep = '\t',
                index_col = 0)
print('inpt len:', len(input_df))
# Out:
# inpt len: 827

# %%
input_df
# Out:
#                       System       Cancer_type  entrz_tran_1  entrz_tran_2  \
# improve_sample_id
# smpl_id_101        cell-line      glioblastoma      4.173927      0.176323
# smpl_id_1036       cell-line       colon-adeno      0.000000      0.622930
# smpl_id_1059       cell-line  pancreatic-adeno      0.000000      0.000000
# smpl_id_106        cell-line  pancreatic-adeno      0.275007      0.111031
# smpl_id_108        cell-line        lung-adeno      3.636915      0.321928
# ...                      ...               ...           ...           ...
# smpl_id_983        cell-line       colon-adeno      0.014355      0.070389
# smpl_id_988        cell-line       colon-adeno      2.032101      0.333424
# smpl_id_994        cell-line       colon-adeno      0.056584      0.014355
# smpl_id_995        cell-line       colon-adeno      0.310340      0.042644
# smpl_id_996        cell-line       colon-adeno      0.176323      3.072106
#
#                    entrz_tran_9  entrz_tran_10  entrz_tran_12  entrz_tran_13  \
# improve_sample_id
# smpl_id_101            3.414136       0.594549       0.722466       2.097611
# smpl_id_1036           3.379898       0.070389       0.526069       0.028569
# smpl_id_1059           4.415488       0.000000       0.042644       2.482848
# smpl_id_106            2.160275       0.124328       1.752749       0.189034
# smpl_id_108            4.032982       0.275007       0.545968       0.201634
# ...                         ...            ...            ...            ...
# smpl_id_983            2.550901       2.080658       0.014355       0.963474
# smpl_id_988            3.694880       1.622930       1.292782       3.504620
# smpl_id_994            1.731183       0.000000       0.150560       0.000000
# smpl_id_995            3.070389       2.903038       0.475085       0.042644
# smpl_id_996            2.568032       3.541019       0.321928       2.189034
#
#                    entrz_tran_14  entrz_tran_15  ...  entrz_tran_111064649  \
# improve_sample_id                                ...
# smpl_id_101             5.979339       0.286881  ...              0.000000
# smpl_id_1036            6.619853       0.042644  ...              0.000000
# smpl_id_1059            6.130725       0.028569  ...              0.028569
# smpl_id_106             6.415319       0.400538  ...              0.000000
# smpl_id_108             6.982423       0.111031  ...              0.000000
# ...                          ...            ...  ...                   ...
# smpl_id_983             6.648609       0.042644  ...              0.941106
# smpl_id_988             6.993335       0.150560  ...              0.000000
# smpl_id_994             6.889474       0.056584  ...              0.000000
# smpl_id_995             7.356232       0.111031  ...              3.016140
# smpl_id_996             7.382840       0.084064  ...              3.028569
#
#                    entrz_tran_111188157  entrz_tran_112441426  \
# improve_sample_id
# smpl_id_101                    0.150560              0.000000
# smpl_id_1036                   0.000000              0.000000
# smpl_id_1059                   0.137504              0.000000
# smpl_id_106                    0.333424              0.000000
# smpl_id_108                    0.070389              0.000000
# ...                                 ...                   ...
# smpl_id_983                    0.000000              0.000000
# smpl_id_988                    0.000000              0.000000
# smpl_id_994                    0.028569              0.000000
# smpl_id_995                    0.070389              0.000000
# smpl_id_996                    0.000000              0.014355
#
#                    entrz_tran_112441434  entrz_tran_112694756  \
# improve_sample_id
# smpl_id_101                    1.769772              3.155425
# smpl_id_1036                   1.918386              3.190615
# smpl_id_1059                   2.601697              1.356144
# smpl_id_106                    2.292782              3.261531
# smpl_id_108                    1.427606              3.740928
# ...                                 ...                   ...
# smpl_id_983                    1.395063              1.918386
# smpl_id_988                    2.358959              1.565597
# smpl_id_994                    2.887525              3.862947
# smpl_id_995                    1.807355              2.650765
# smpl_id_996                    2.364572              3.211012
#
#                    entrz_tran_113455421  entrz_tran_113523638  \
# improve_sample_id
# smpl_id_101                    3.920293                   0.0
# smpl_id_1036                   3.843984                   0.0
# smpl_id_1059                   3.757023                   0.0
# smpl_id_106                    4.066950                   0.0
# smpl_id_108                    3.171527                   0.0
# ...                                 ...                   ...
# smpl_id_983                    2.049631                   0.0
# smpl_id_988                    3.258519                   0.0
# smpl_id_994                    4.325530                   0.0
# smpl_id_995                    3.992768                   0.0
# smpl_id_996                    3.341986                   0.0
#
#                    entrz_tran_114483833  entrz_tran_115253422  \
# improve_sample_id
# smpl_id_101                    0.163499              1.700440
# smpl_id_1036                   0.000000              0.978196
# smpl_id_1059                   0.000000              2.046142
# smpl_id_106                    0.056584              2.130931
# smpl_id_108                    0.000000              2.185867
# ...                                 ...                   ...
# smpl_id_983                    0.028569              1.111031
# smpl_id_988                    0.000000              2.066950
# smpl_id_994                    0.000000              1.929791
# smpl_id_995                    0.000000              1.007196
# smpl_id_996                    0.000000              0.659925
#
#                    entrz_tran_116033993
# improve_sample_id
# smpl_id_101                         0.0
# smpl_id_1036                        0.0
# smpl_id_1059                        0.0
# smpl_id_106                         0.0
# smpl_id_108                         0.0
# ...                                 ...
# smpl_id_983                         0.0
# smpl_id_988                         0.0
# smpl_id_994                         0.0
# smpl_id_995                         0.0
# smpl_id_996                         0.0
#
# [827 rows x 19133 columns]

# %%
input_df.isna().sum().sum()
# Out:
# 0

# %%
# MBatch load
corr_df = pd.read_csv(
                mb_pths[path_index_toggle],
                sep = '\t',
                index_col = 0)
corr_pths = mb_pths
print('MB corr len:', len(corr_df))
corr_mthd_title = 'MBatch'
mthd_file_disk_name = 'mbatch'
latent_dim = 'NA'
# Out:
# MB corr len: 827

# %%
# Quant-resc load
corr_df = pd.read_csv(
                qs_pths[path_index_toggle],
                sep = '\t',
                index_col = 0)
corr_pths = qs_pths
print('QS corr len:', len(corr_df))
corr_mthd_title = 'Quant-resc'
mthd_file_disk_name = 'quant-resc'
latent_dim = 'NA'
# Out:
# QS corr len: 827

# %%
corr_df.isna().sum().sum()
# Out:
# 242730

# %%
corr_df.isna().any(axis=0).sum()
# Out:
# 930

# %%
corr_df.shape
# Out:
# (827, 19125)

# %%
corr_df = corr_df.loc[:, corr_df.isna().any(axis=0) == False]

# %%
corr_df.shape
# Out:
# (827, 18195)

# %%
corr_df.isna().sum().sum()
# Out:
# 0

# %%
vae_pths

# %%
# VAE load
print(vae_pths[path_index_toggle])
corr_df = pd.read_csv(
        vae_pths[path_index_toggle],
        sep = '\t',
        index_col = 0)
corr_pths = vae_pths
print('vae latent len:', len(corr_df))

# corr_mthd_title = 'VAE_beta-classifier'
corr_mthd_title = 'VAE_classifier'
# corr_mthd_title = 'VAE_cntrstv-loss'
# corr_mthd_title = 'VAE_disc'

# mthd_file_disk_name = 'vae_beta-classifier'
mthd_file_disk_name = 'vae_classifier'
# mthd_file_disk_name = 'vae_cntrstv-loss'
# mthd_file_disk_name = 'vae_disc'

latent_dim = 50
# Out:
# ../results/r72/vae/classifier/nc5_transcriptomics_cell-line+CPTAC.classifier_50-ltnt-dim_100-epchs.tsv
# vae latent len: 827

# %%
corr_df

# %%
# 
#Tybalt load
corr_df = pd.read_csv(
            tb_pths[path_index_toggle],
            sep = '\t',
            index_col = 0)
corr_pths = tb_pths
print('Tybalt latent len:', len(corr_df))
corr_mthd_title = 'Tybalt baseline VAE'
mthd_file_disk_name = 'tybalt'

# %%
sys_togg

# %%
inp_mdl_sys_train_df

# %%
corr_mdl_sys_train_df # disc index

# %% [markdown]
# ### Clf

# %%
path_index_toggle
# Out:
# 0

# %%
# print('Begin clf on ', phase)
print('Begin sub-sampled, matched-cross val\n classification evals')
print(' ')
print('Input file:\n', inp_pths[path_index_toggle].split('/')[-1])
print('Correction file:\n', corr_pths[path_index_toggle].split('/')[-1])
print(' ')

clf_list = [RandomForestClassifier(max_depth=2, random_state=0),
            tree.DecisionTreeClassifier(),
            LogisticRegression(random_state=0, max_iter=5000),
            make_pipeline(StandardScaler(),
                LinearSVC(dual="auto", random_state=0,
                          max_iter=100000, tol=1e-5))]

# Subset training input
# inp_mdl_sys_train_df = input_df[input_df.System == 'cell-line']

# Subset correction object, toggle with file read
# corr_mdl_sys_train_df = corr_df[corr_df.System == 'cell-line']
print('path_index_toggle', path_index_toggle)
print('sys_togg', sys_togg)
if path_index_toggle == 1:
# HCMI
# Subset training input
    inp_mdl_sys_train_df = input_df[input_df.System == sys_togg]

# Subset correction object, toggle with file read
    corr_mdl_sys_train_df = corr_df[corr_df.System == sys_togg]
else:
    print('cell-line')
    print(sys_togg)
    inp_mdl_sys_train_df = input_df[input_df.System == sys_togg]
    corr_mdl_sys_train_df = corr_df[corr_df.System == sys_togg]
# List of dicts
results = []

for cross_val in range(30): # chk
    print('cross_val', cross_val)

    # Train set sub-sample, input - X and y
    X_input = inp_mdl_sys_train_df.iloc[:, 2:]
    X_input = X_input.sample(round(len(X_input)*.85))
    y_input = inp_mdl_sys_train_df[inp_mdl_sys_train_df.index.isin(
                                        X_input.index)].Cancer_type

    # Train set sub-sample, corr - X and y
    X_corr = corr_mdl_sys_train_df.iloc[:, 2:]
    X_corr = X_corr[X_corr.index.isin(X_input.index)]
    y_corr = corr_mdl_sys_train_df[corr_mdl_sys_train_df.index.isin(
                                        X_corr.index)].Cancer_type

    # Test set extraction, input and corr
    CPTAC_input = input_df[input_df.System == 'cptac']
    CPTAC_corr = corr_df[corr_df.System == 'cptac']

    # print(len(CPTAC_input))
    # print(len(CPTAC_corr))
    
    clf_i_list = ['RF', 'DT', 'LR', 'SVM']

    # Classifier loop, input
    print('Start input loop')
    input_score_list = []
    for clf_i in range(len(clf_list)):
        clf = clf_list[clf_i]
        clf.fit(X_input,
                y_input)
    
        score = f1_score(CPTAC_input.Cancer_type,
                         clf.predict(CPTAC_input.iloc[:, 2:]),
                         average = 'weighted')
        
        results.append({
            'cross_val': cross_val,
            'classifier': clf_i_list[clf_i],
            'score': score,
            'type': 'input'
        })
        # break
    # Classifier loop, correction method
    print('Start correction eval loop')
    for clf_i in range(len(clf_list)):
        clf = clf_list[clf_i]
        clf.fit(X_corr,
                y_corr)
    
        score = f1_score(CPTAC_corr.Cancer_type,
                         clf.predict(CPTAC_corr.iloc[:, 2:]),
                         average = 'weighted')
        results.append({
            'cross_val': cross_val,
            'classifier': clf_i_list[clf_i],
            'score': score,
            'type': 'corrected'
        })

    # print('end cross fold')
    print(' ')
    # break
print('done')
# Out:
# Begin sub-sampled, matched-cross val
#  classification evals
#
# Input file:
#  nc5_transcriptomics_cell-line+CPTAC.input-data.tsv
# Correction file:
#  nc5_transcriptomics_cell-line+CPTAC.classifier_50-ltnt-dim_100-epchs.tsv
#
# path_index_toggle 0
# sys_togg cell-line
# cell-line
# cell-line
# cross_val 0
# Start input loop
# Start correction eval loop
#
# cross_val 1
# Start input loop
# Start correction eval loop
#
# cross_val 2
# Start input loop
# Start correction eval loop
#
# cross_val 3
# Start input loop
# Start correction eval loop
#
# cross_val 4
# Start input loop
# Start correction eval loop
#
# cross_val 5
# Start input loop

# %%
results_df = pd.DataFrame(results)
# results_df

# %%
pd.options.display.max_rows = 300

# %%
results_df
# Out:
#      cross_val classifier     score       type
# 0            0         RF  0.058059      input
# 1            0         DT  0.098099      input
# 2            0         LR  0.098099      input
# 3            0        SVM  0.099652      input
# 4            0         RF  0.113705  corrected
# 5            0         DT  0.198079  corrected
# 6            0         LR  0.205505  corrected
# 7            0        SVM  0.209640  corrected
# 8            1         RF  0.071434      input
# 9            1         DT  0.058146      input
# 10           1         LR  0.107309      input
# 11           1        SVM  0.157388      input
# 12           1         RF  0.102978  corrected
# 13           1         DT  0.220128  corrected
# 14           1         LR  0.196150  corrected
# 15           1        SVM  0.193602  corrected
# 16           2         RF  0.056351      input
# 17           2         DT  0.055993      input
# 18           2         LR  0.003710      input
# 19           2        SVM  0.133202      input
# 20           2         RF  0.109784  corrected
# 21           2         DT  0.219603  corrected
# 22           2         LR  0.196714  corrected
# 23           2        SVM  0.201171  corrected
# 24           3         RF  0.064309      input
# 25           3         DT  0.098099      input
# 26           3         LR  0.118920      input
# 27           3        SVM  0.163995      input
# 28           3         RF  0.071464  corrected
# 29           3         DT  0.200579  corrected
# 30           3         LR  0.201305  corrected
# 31           3        SVM  0.200836  corrected
# 32           4         RF  0.063130      input
# 33           4         DT  0.054196      input
# 34           4         LR  0.084100      input
# 35           4        SVM  0.132121      input
# 36           4         RF  0.076418  corrected
# 37           4         DT  0.189187  corrected
# 38           4         LR  0.211087  corrected
# 39           4        SVM  0.220305  corrected
# 40           5         RF  0.056653      input
# 41           5         DT  0.152599      input
# 42           5         LR  0.120439      input
# 43           5        SVM  0.116072      input
# 44           5         RF  0.094480  corrected
# 45           5         DT  0.218442  corrected
# 46           5         LR  0.194299  corrected
# 47           5        SVM  0.193552  corrected
# 48           6         RF  0.061142      input
# 49           6         DT  0.053057      input
# 50           6         LR  0.056133      input
# 51           6        SVM  0.169729      input
# 52           6         RF  0.080259  corrected
# 53           6         DT  0.201813  corrected
# 54           6         LR  0.185932  corrected
# 55           6        SVM  0.191999  corrected
# 56           7         RF  0.098099      input
# 57           7         DT  0.058059      input
# 58           7         LR  0.202274      input
# 59           7        SVM  0.063249      input
# 60           7         RF  0.082550  corrected
# 61           7         DT  0.222138  corrected
# 62           7         LR  0.187187  corrected
# 63           7        SVM  0.200461  corrected
# 64           8         RF  0.152702      input
# 65           8         DT  0.058059      input
# 66           8         LR  0.067904      input
# 67           8        SVM  0.063249      input
# 68           8         RF  0.105761  corrected
# 69           8         DT  0.209176  corrected
# 70           8         LR  0.193520  corrected
# 71           8        SVM  0.219646  corrected
# 72           9         RF  0.103947      input
# 73           9         DT  0.248875      input
# 74           9         LR  0.086570      input
# 75           9        SVM  0.110118      input
# 76           9         RF  0.081303  corrected
# 77           9         DT  0.188621  corrected
# 78           9         LR  0.177669  corrected
# 79           9        SVM  0.178524  corrected
# 80          10         RF  0.064309      input
# 81          10         DT  0.063249      input
# 82          10         LR  0.056152      input
# 83          10        SVM  0.062860      input
# 84          10         RF  0.088447  corrected
# 85          10         DT  0.207966  corrected
# 86          10         LR  0.199414  corrected
# 87          10        SVM  0.206768  corrected
# 88          11         RF  0.117688      input
# 89          11         DT  0.050327      input
# 90          11         LR  0.098099      input
# 91          11        SVM  0.064600      input
# 92          11         RF  0.098700  corrected
# 93          11         DT  0.216694  corrected
# 94          11         LR  0.211969  corrected
# 95          11        SVM  0.210821  corrected
# 96          12         RF  0.095167      input
# 97          12         DT  0.097638      input
# 98          12         LR  0.098238      input
# 99          12        SVM  0.176456      input
# 100         12         RF  0.120701  corrected
# 101         12         DT  0.166470  corrected
# 102         12         LR  0.192270  corrected
# 103         12        SVM  0.197439  corrected
# 104         13         RF  0.064309      input
# 105         13         DT  0.098238      input
# 106         13         LR  0.064499      input
# 107         13        SVM  0.079801      input
# 108         13         RF  0.085181  corrected
# 109         13         DT  0.186709  corrected
# 110         13         LR  0.205957  corrected
# 111         13        SVM  0.197988  corrected
# 112         14         RF  0.213297      input
# 113         14         DT  0.173566      input
# 114         14         LR  0.033756      input
# 115         14        SVM  0.260303      input
# 116         14         RF  0.096405  corrected
# 117         14         DT  0.196998  corrected
# 118         14         LR  0.216347  corrected
# 119         14        SVM  0.225910  corrected
# 120         15         RF  0.051497      input
# 121         15         DT  0.068047      input
# 122         15         LR  0.099081      input
# 123         15        SVM  0.053596      input
# 124         15         RF  0.070187  corrected
# 125         15         DT  0.195211  corrected
# 126         15         LR  0.215783  corrected
# 127         15        SVM  0.211712  corrected
# 128         16         RF  0.064309      input
# 129         16         DT  0.046951      input
# 130         16         LR  0.063249      input
# 131         16        SVM  0.157053      input
# 132         16         RF  0.080558  corrected
# 133         16         DT  0.218803  corrected
# 134         16         LR  0.196447  corrected
# 135         16        SVM  0.196879  corrected
# 136         17         RF  0.139318      input
# 137         17         DT  0.053620      input
# 138         17         LR  0.239886      input
# 139         17        SVM  0.282350      input
# 140         17         RF  0.103032  corrected
# 141         17         DT  0.207108  corrected
# 142         17         LR  0.216773  corrected
# 143         17        SVM  0.188961  corrected
# 144         18         RF  0.064309      input
# 145         18         DT  0.101842      input
# 146         18         LR  0.179446      input
# 147         18        SVM  0.066125      input
# 148         18         RF  0.082430  corrected
# 149         18         DT  0.232807  corrected
# 150         18         LR  0.204097  corrected
# 151         18        SVM  0.190484  corrected
# 152         19         RF  0.064309      input
# 153         19         DT  0.029005      input
# 154         19         LR  0.064309      input
# 155         19        SVM  0.236218      input
# 156         19         RF  0.100623  corrected
# 157         19         DT  0.215505  corrected
# 158         19         LR  0.213516  corrected
# 159         19        SVM  0.215222  corrected
# 160         20         RF  0.041915      input
# 161         20         DT  0.079532      input
# 162         20         LR  0.098099      input
# 163         20        SVM  0.063436      input
# 164         20         RF  0.070900  corrected
# 165         20         DT  0.206811  corrected
# 166         20         LR  0.193262  corrected
# 167         20        SVM  0.199023  corrected
# 168         21         RF  0.117665      input
# 169         21         DT  0.098099      input
# 170         21         LR  0.058059      input
# 171         21        SVM  0.050095      input
# 172         21         RF  0.083572  corrected
# 173         21         DT  0.195320  corrected
# 174         21         LR  0.179998  corrected
# 175         21        SVM  0.180288  corrected
# 176         22         RF  0.064309      input
# 177         22         DT  0.064309      input
# 178         22         LR  0.190678      input
# 179         22        SVM  0.063249      input
# 180         22         RF  0.084649  corrected
# 181         22         DT  0.203196  corrected
# 182         22         LR  0.187458  corrected
# 183         22        SVM  0.195067  corrected
# 184         23         RF  0.064309      input
# 185         23         DT  0.073087      input
# 186         23         LR  0.020796      input
# 187         23        SVM  0.140606      input
# 188         23         RF  0.115657  corrected
# 189         23         DT  0.212394  corrected
# 190         23         LR  0.199718  corrected
# 191         23        SVM  0.212050  corrected
# 192         24         RF  0.098518      input
# 193         24         DT  0.151220      input
# 194         24         LR  0.074974      input
# 195         24        SVM  0.044754      input
# 196         24         RF  0.080017  corrected
# 197         24         DT  0.215994  corrected
# 198         24         LR  0.210306  corrected
# 199         24        SVM  0.213611  corrected
# 200         25         RF  0.064309      input
# 201         25         DT  0.053057      input
# 202         25         LR  0.030024      input
# 203         25        SVM  0.261626      input
# 204         25         RF  0.101534  corrected
# 205         25         DT  0.216147  corrected
# 206         25         LR  0.191841  corrected
# 207         25        SVM  0.204045  corrected
# 208         26         RF  0.065432      input
# 209         26         DT  0.078279      input
# 210         26         LR  0.098099      input
# 211         26        SVM  0.144908      input
# 212         26         RF  0.083079  corrected
# 213         26         DT  0.192946  corrected
# 214         26         LR  0.208761  corrected
# 215         26        SVM  0.206418  corrected
# 216         27         RF  0.120625      input
# 217         27         DT  0.058059      input
# 218         27         LR  0.098099      input
# 219         27        SVM  0.043151      input
# 220         27         RF  0.115466  corrected
# 221         27         DT  0.189165  corrected
# 222         27         LR  0.205162  corrected
# 223         27        SVM  0.194722  corrected
# 224         28         RF  0.064309      input
# 225         28         DT  0.078765      input
# 226         28         LR  0.064309      input
# 227         28        SVM  0.117599      input
# 228         28         RF  0.089766  corrected
# 229         28         DT  0.188230  corrected
# 230         28         LR  0.198931  corrected
# 231         28        SVM  0.186445  corrected
# 232         29         RF  0.216831      input
# 233         29         DT  0.058059      input
# 234         29         LR  0.099108      input
# 235         29        SVM  0.106630      input
# 236         29         RF  0.108180  corrected
# 237         29         DT  0.188455  corrected
# 238         29         LR  0.208767  corrected
# 239         29        SVM  0.207792  corrected

# %%
print(sys_file_names)
print(mthd_file_disk_name)
# Out:
# cell-line+CPTAC
# vae_beta-classifier

# %%
ls ../results/r72/
# Out:
# 2024-03-12/               mbatch/                   tybalt/
# 2024-03-14/               quant-resc/               vae/
# 2024-03-19/               results_readme.txt        x-fer_long-frame_archive/

# %%
results_df.to_csv('../results/r72/'+
                  production_date+'/input-'+mthd_file_disk_name+
                  '_clf-eval-n4_x-val=30_'+sys_file_names+'.tsv',
                 sep = '\t')

# %%
sample_count_lbl
# Out:
# 'Cell line'

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a figure and axis
plt.figure(figsize=(10, 7))

# Plot
sns.boxplot(data=results_df, x='classifier', y='score',
            hue='type', palette='Set2')

# cancer_count = 5
# cancer_count = 5

# Adding title and labels
plt.title('Classification Prediction Performance on Input'+
          ' vs Corrected Data\nTrain on '+mdl_sys_inline+' 85% subsample, '+
          'predict on CPTAC, n cancers = '+str(cancer_count)+
          '\n'+corr_mthd_title+', transcriptomics', fontsize=16)
plt.xlabel('Classifier', fontsize=15)
plt.ylabel('F1 Score', fontsize=15)
plt.legend(title='Data Type', fontsize=12)

plt.annotate(sample_count_lbl+' samples: {}'.format(len(inp_mdl_sys_train_df))+
             '\nCPTAC samples: {}'.format(len(CPTAC_input))+
             '\nLatent dim: '+str(latent_dim)+'\nFeature count: {}'.format(
                 len(X_input.columns)), 
                 # xy=(0.03, 0.85), # Tybalt
                 xy=(0.55, 0.85), # 
                 xycoords='axes fraction', 
                 bbox=dict(boxstyle='round, pad=0.5', fc='white', ec='black'),
                 fontsize=12)

# Display the plot
plt.tight_layout()
plt.savefig('../results/r72/'+
            production_date+'/input-'+mthd_file_disk_name+
            '_clf-eval-n4_x-val=30_'+sys_file_names+'.png',
            dpi = 300)
# plt.show()

# %%
X_input
