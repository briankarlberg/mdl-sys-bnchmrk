# %% [markdown]
# # R72

# %%
# R72: (second pass)
    # cell line -> CPTAC, 5 cancer types
    # HCMI -> CPTAC, 2 cancer types
# methods to bar plot test for r8

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
production_date = '2024-03-19'

# %%
# Data handling & comparision setup
import pandas as pd
import glob
import itertools

# Feature selection, RFE
from sklearn.feature_selection import RFE
from sklearn.svm import SVR

# Import 3 SciKit Learn classifiers
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.linear_model import LogisticRegression

# SVM
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# Classification setup and eval
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import statistics

# Plotting
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set data paths

# %% [markdown]
# #### Input read

# %%
# phase = 'Input', need for all comparisons
inp_pths = sorted(
    glob.glob('../data/r72/*.tsv'), reverse = True)
inp_pths
# Out:
# ['../data/r72/nc5_transcriptomics_cell-line+CPTAC.input-data.tsv',
#  '../data/r72/nc2_transcriptomics_HCMI+CPTAC.input-data.tsv']

# %% [markdown]
# ##### Check label capitalization on input paths

# %%
for inp_pth in inp_pths:
    df = pd.read_csv(
        inp_pth, sep = '\t', index_col = 0)
    print(df.System.unique())

# %%
# Conclusion - MBatch rebuild script converted to caps
    # archive caps versions
    # conver to lowercase and re-write

# %% [markdown]
# #### MBatch

# %%
# phase = 'MBatch'
mb_pths = sorted(
    glob.glob('../results/r72/mbatch/*.tsv'), reverse = True)
mb_pths

# %% [markdown]
# ##### MBatch i-o de-capitilize

# %%
for mb_pth in mb_pths:
    df = pd.read_csv(
        mb_pth, sep = '\t', index_col = 0)
    print(df.System.unique())

# %%
mb_pths = sorted(
    glob.glob('../results/r72/mbatch/cap_lbls_archive/*.tsv'), reverse = True)
for mb_pth in mb_pths:
    # print(mb_pth)
    f_nm = mb_pth.split('/')[-1]
    df = pd.read_csv(
        mb_pth, sep = '\t', index_col = 0)
    print(df.System.unique())

    df['System'] = df['System'].str.lower()
    
    print(df.System.unique())

    df.to_csv(
        '../results/r72/mbatch/'+f_nm,
        sep = '\t')
    print(' ')
    # break

# %%
f_nm = mb_pth.split('/')[-1]

# %%
f_nm

# %% [markdown]
# #### Qaunt rescale

# %%
qs_pths = sorted(
    glob.glob('../results/r72/quant-resc/*.tsv'), reverse = True)
qs_pths

# %% [markdown]
# #### VAE

# %%
ls ../results/r72/vae/

# %%
ls ../results/r72/vae/beta-classifier/

# %%
# phase = 'VAE beta-classifier'
vae_pths = sorted(
    glob.glob('../results/r72/vae/beta-classifier/*.tsv'), reverse = True)
vae_pths

# %%
ls ../results/r72/vae/classifier/

# %%
# phase = 'VAE classifier'
vae_pths = sorted(
    glob.glob('../results/r72/vae/classifier/*.tsv'), reverse = True)
vae_pths

# %%
ls ../results/r72/vae/con_loss/

# %%
# phase = 'VAE con_loss'
vae_pths = sorted(
    glob.glob('../results/r72/vae/con_loss/*.tsv'), reverse = True)
vae_pths

# %%
ls ../results/r72/vae/disc/

# %%
# phase = 'VAE disc'
vae_pths = sorted(
    glob.glob('../results/r72/vae/disc/*.tsv'), reverse = True)
vae_pths
# Out:
# ['../results/r72/vae/disc/nc5_transcriptomics_cell-line+CPTAC.disc_50-ltnt-dim_100-epchs.tsv',
#  '../results/r72/vae/disc/nc2_transcriptomics_HCMI+CPTAC.disc_50-ltnt-dim_100-epchs.tsv']

# %% [markdown]
# #### Tybalt

# %%
ls ../results/r72/tybalt/

# %%
tb_pths = sorted(
    glob.glob('../results/r72/tybalt/*.tsv'), reverse = True)
tb_pths

# %%
# skip RFE for now, start with 3 clf on raw and mbatch

# %% [markdown]
# ### RFE

# %%
for pth in inp:
    df = pd.read_csv(
        pth, sep = '\t', index_col = 0)
    X = df.iloc[:, 2:]
    break

# %%
df

# %%
estimator = SVR(kernel="linear")
rfe = RFE(estimator=estimator, n_features_to_select=10, step=0.5)
file_n = pd.read_csv(pth, sep = '\t', index_col = 0) # read validation split file
X = file_n.iloc[:, 1:]
y = file_n.iloc[:, 0]
rfe.fit(X, y)
mask = rfe.support_
vs_dict[vs] = json.dumps(list(X.columns[mask]))

# %% [markdown]
# ### Subsample cross val devel

# %%
# Sub-sample input at 80%
# match row index on corr df

# %%
inp_pths

# %%
tb_pths

# %%
vae_pths

# %%
# Questions - sub-sample on only the input?
# Predict on entire CPTAC?

# split before subsample? - yes, that's what X was

# %% [markdown]
# ### Load data

# %%
path_index_toggle = 0
cancer_count = 5
sys_togg = 'cell-line'
sys_file_names = 'cell-line+CPTAC'
sample_count_lbl = 'Cell line'
mdl_sys_inline = 'cell line'

# %%
path_index_toggle = 1
cancer_count = 2
sys_togg = 'hcmi'
sys_file_names = 'HMCI+CPTAC'
sample_count_lbl = 'HCMI'
mdl_sys_inline = 'HCMI'

# %%
path_index_toggle

# %%
inp_pths

# %%
# Input load
input_df = pd.read_csv(
                inp_pths[path_index_toggle], # nc5 or nc2 file
                sep = '\t',
                index_col = 0)
print('inpt len:', len(input_df))
# Out:
# inpt len: 827

# %%
input_df

# %%
input_df.isna().sum().sum()
# Out:
# 0

# %%
# MBatch load
corr_df = pd.read_csv(
                mb_pths[path_index_toggle],
                sep = '\t',
                index_col = 0)
corr_pths = mb_pths
print('MB corr len:', len(corr_df))
corr_mthd_title = 'MBatch'
mthd_file_disk_name = 'mbatch'
latent_dim = 'NA'

# %%
# Quant-resc load
corr_df = pd.read_csv(
                qs_pths[path_index_toggle],
                sep = '\t',
                index_col = 0)
corr_pths = qs_pths
print('QS corr len:', len(corr_df))
corr_mthd_title = 'Quant-resc'
mthd_file_disk_name = 'quant-resc'
latent_dim = 'NA'

# %%
corr_df.isna().sum().sum()

# %%
corr_df.isna().any(axis=0).sum()

# %%
corr_df.shape

# %%
corr_df = corr_df.loc[:, corr_df.isna().any(axis=0) == False]

# %%
corr_df.shape

# %%
corr_df.isna().sum().sum()

# %%
vae_pths
# Out:
# ['../results/r72/vae/disc/nc5_transcriptomics_cell-line+CPTAC.disc_50-ltnt-dim_100-epchs.tsv',
#  '../results/r72/vae/disc/nc2_transcriptomics_HCMI+CPTAC.disc_50-ltnt-dim_100-epchs.tsv']

# %%
# VAE load
print(vae_pths[path_index_toggle])
corr_df = pd.read_csv(
        vae_pths[path_index_toggle],
        sep = '\t',
        index_col = 0)
corr_pths = vae_pths
print('vae latent len:', len(corr_df))

# corr_mthd_title = 'VAE_beta-classifier'
# corr_mthd_title = 'VAE_classifier'
# corr_mthd_title = 'VAE_cntrstv-loss'
corr_mthd_title = 'VAE_disc'

# mthd_file_disk_name = 'vae_beta-classifier'
# mthd_file_disk_name = 'vae_classifier'
# mthd_file_disk_name = 'vae_cntrstv-loss'
mthd_file_disk_name = 'vae_disc'

latent_dim = 50
# Out:
# ../results/r72/vae/disc/nc5_transcriptomics_cell-line+CPTAC.disc_50-ltnt-dim_100-epchs.tsv
# vae latent len: 827

# %%
corr_df

# %%
# 
#Tybalt load
corr_df = pd.read_csv(
            tb_pths[path_index_toggle],
            sep = '\t',
            index_col = 0)
corr_pths = tb_pths
print('Tybalt latent len:', len(corr_df))
corr_mthd_title = 'Tybalt baseline VAE'
mthd_file_disk_name = 'tybalt'

# %%
sys_togg

# %%
inp_mdl_sys_train_df

# %%
corr_mdl_sys_train_df # disc index

# %% [markdown]
# ### Clf

# %%
path_index_toggle

# %%
# print('Begin clf on ', phase)
print('Begin sub-sampled, matched-cross val\n classification evals')
print(' ')
print('Input file:\n', inp_pths[path_index_toggle].split('/')[-1])
print('Correction file:\n', corr_pths[path_index_toggle].split('/')[-1])
print(' ')

clf_list = [RandomForestClassifier(max_depth=2, random_state=0),
            tree.DecisionTreeClassifier(),
            LogisticRegression(random_state=0, max_iter=5000),
            make_pipeline(StandardScaler(),
                LinearSVC(dual="auto", random_state=0,
                          max_iter=100000, tol=1e-5))]

# Subset training input
# inp_mdl_sys_train_df = input_df[input_df.System == 'cell-line']

# Subset correction object, toggle with file read
# corr_mdl_sys_train_df = corr_df[corr_df.System == 'cell-line']
print('path_index_toggle', path_index_toggle)
print('sys_togg', sys_togg)
if path_index_toggle == 1:
# HCMI
# Subset training input
    inp_mdl_sys_train_df = input_df[input_df.System == sys_togg]

# Subset correction object, toggle with file read
    corr_mdl_sys_train_df = corr_df[corr_df.System == sys_togg]
else:
    print('cell-line')
    print(sys_togg)
    inp_mdl_sys_train_df = input_df[input_df.System == sys_togg]
    corr_mdl_sys_train_df = corr_df[corr_df.System == sys_togg]
# List of dicts
results = []

for cross_val in range(30): # chk
    print('cross_val', cross_val)

    # Train set sub-sample, input - X and y
    X_input = inp_mdl_sys_train_df.iloc[:, 2:]
    X_input = X_input.sample(round(len(X_input)*.85))
    y_input = inp_mdl_sys_train_df[inp_mdl_sys_train_df.index.isin(
                                        X_input.index)].Cancer_type

    # Train set sub-sample, corr - X and y
    X_corr = corr_mdl_sys_train_df.iloc[:, 2:]
    X_corr = X_corr[X_corr.index.isin(X_input.index)]
    y_corr = corr_mdl_sys_train_df[corr_mdl_sys_train_df.index.isin(
                                        X_corr.index)].Cancer_type

    # Test set extraction, input and corr
    CPTAC_input = input_df[input_df.System == 'cptac']
    CPTAC_corr = corr_df[corr_df.System == 'cptac']

    # print(len(CPTAC_input))
    # print(len(CPTAC_corr))
    
    clf_i_list = ['RF', 'DT', 'LR', 'SVM']

    # Classifier loop, input
    print('Start input loop')
    input_score_list = []
    for clf_i in range(len(clf_list)):
        clf = clf_list[clf_i]
        clf.fit(X_input,
                y_input)
    
        score = f1_score(CPTAC_input.Cancer_type,
                         clf.predict(CPTAC_input.iloc[:, 2:]),
                         average = 'weighted')
        
        results.append({
            'cross_val': cross_val,
            'classifier': clf_i_list[clf_i],
            'score': score,
            'type': 'input'
        })
        # break
    # Classifier loop, correction method
    print('Start correction eval loop')
    for clf_i in range(len(clf_list)):
        clf = clf_list[clf_i]
        clf.fit(X_corr,
                y_corr)
    
        score = f1_score(CPTAC_corr.Cancer_type,
                         clf.predict(CPTAC_corr.iloc[:, 2:]),
                         average = 'weighted')
        results.append({
            'cross_val': cross_val,
            'classifier': clf_i_list[clf_i],
            'score': score,
            'type': 'corrected'
        })

    # print('end cross fold')
    print(' ')
    # break
print('done')
# Out:
# Begin sub-sampled, matched-cross val
#  classification evals
#
# Input file:
#  nc5_transcriptomics_cell-line+CPTAC.input-data.tsv
# Correction file:
#  nc5_transcriptomics_cell-line+CPTAC.disc_50-ltnt-dim_100-epchs.tsv
#
# path_index_toggle 0
# sys_togg cell-line
# cell-line
# cell-line
# cross_val 0
# Start input loop
# Start correction eval loop
#
# cross_val 1
# Start input loop
# Start correction eval loop
#
# cross_val 2
# Start input loop
# Start correction eval loop
#
# cross_val 3
# Start input loop
# Start correction eval loop
#
# cross_val 4
# Start input loop
# Start correction eval loop
#
# cross_val 5
# Start input loop
# Start correction eval loop
#
# cross_val 6
# Start input loop
# Start correction eval loop
#
# cross_val 7
# Start input loop
# Start correction eval loop
#
# cross_val 8
# Start input loop
# Start correction eval loop
#
# cross_val 9
# Start input loop
# Start correction eval loop
#
# cross_val 10
# Start input loop
# Start correction eval loop
#
# cross_val 11
# Start input loop
# Start correction eval loop
#
# cross_val 12
# Start input loop
# Start correction eval loop
#
# cross_val 13
# Start input loop
# Start correction eval loop
#
# cross_val 14
# Start input loop
# Start correction eval loop
#
# cross_val 15
# Start input loop
# Start correction eval loop
#
# cross_val 16
# Start input loop
# Start correction eval loop
#
# cross_val 17
# Start input loop
# Start correction eval loop
#
# cross_val 18
# Start input loop
# Start correction eval loop
#
# cross_val 19
# Start input loop
# Start correction eval loop
#
# cross_val 20
# Start input loop
# Start correction eval loop
#
# cross_val 21
# Start input loop
# Start correction eval loop
#
# cross_val 22
# Start input loop
# Start correction eval loop
#
# cross_val 23
# Start input loop
# Start correction eval loop
#
# cross_val 24
# Start input loop
# Start correction eval loop
#
# cross_val 25
# Start input loop
# Start correction eval loop
#
# cross_val 26
# Start input loop
# Start correction eval loop
#
# cross_val 27
# Start input loop
# Start correction eval loop
#
# cross_val 28
# Start input loop
# Start correction eval loop
#
# cross_val 29
# Start input loop
# Start correction eval loop
#
# done

# %%
results_df = pd.DataFrame(results)
# results_df

# %%
pd.options.display.max_rows = 300

# %%
results_df
# Out:
#      cross_val classifier     score       type
# 0            0         RF  0.064309      input
# 1            0         DT  0.067904      input
# 2            0         LR  0.065965      input
# 3            0        SVM  0.058893      input
# 4            0         RF  0.064001  corrected
# 5            0         DT  0.187568  corrected
# 6            0         LR  0.228611  corrected
# 7            0        SVM  0.231945  corrected
# 8            1         RF  0.064309      input
# 9            1         DT  0.124243      input
# 10           1         LR  0.053057      input
# 11           1        SVM  0.023418      input
# 12           1         RF  0.074755  corrected
# 13           1         DT  0.185133  corrected
# 14           1         LR  0.230792  corrected
# 15           1        SVM  0.227120  corrected
# 16           2         RF  0.064309      input
# 17           2         DT  0.057592      input
# 18           2         LR  0.154641      input
# 19           2        SVM  0.085367      input
# 20           2         RF  0.070686  corrected
# 21           2         DT  0.178508  corrected
# 22           2         LR  0.226936  corrected
# 23           2        SVM  0.210427  corrected
# 24           3         RF  0.064907      input
# 25           3         DT  0.064309      input
# 26           3         LR  0.016117      input
# 27           3        SVM  0.006929      input
# 28           3         RF  0.089553  corrected
# 29           3         DT  0.202747  corrected
# 30           3         LR  0.198275  corrected
# 31           3        SVM  0.208741  corrected
# 32           4         RF  0.064309      input
# 33           4         DT  0.098099      input
# 34           4         LR  0.064309      input
# 35           4        SVM  0.072260      input
# 36           4         RF  0.067961  corrected
# 37           4         DT  0.191469  corrected
# 38           4         LR  0.199239  corrected
# 39           4        SVM  0.209207  corrected
# 40           5         RF  0.139014      input
# 41           5         DT  0.058059      input
# 42           5         LR  0.148485      input
# 43           5        SVM  0.073940      input
# 44           5         RF  0.079739  corrected
# 45           5         DT  0.208159  corrected
# 46           5         LR  0.183178  corrected
# 47           5        SVM  0.191627  corrected
# 48           6         RF  0.096216      input
# 49           6         DT  0.098099      input
# 50           6         LR  0.089296      input
# 51           6        SVM  0.118340      input
# 52           6         RF  0.076044  corrected
# 53           6         DT  0.195623  corrected
# 54           6         LR  0.210997  corrected
# 55           6        SVM  0.198284  corrected
# 56           7         RF  0.064309      input
# 57           7         DT  0.053057      input
# 58           7         LR  0.066473      input
# 59           7        SVM  0.070591      input
# 60           7         RF  0.071324  corrected
# 61           7         DT  0.216838  corrected
# 62           7         LR  0.219986  corrected
# 63           7        SVM  0.220743  corrected
# 64           8         RF  0.058059      input
# 65           8         DT  0.058059      input
# 66           8         LR  0.053848      input
# 67           8        SVM  0.027743      input
# 68           8         RF  0.085550  corrected
# 69           8         DT  0.174103  corrected
# 70           8         LR  0.256636  corrected
# 71           8        SVM  0.235225  corrected
# 72           9         RF  0.053620      input
# 73           9         DT  0.058059      input
# 74           9         LR  0.256195      input
# 75           9        SVM  0.023381      input
# 76           9         RF  0.070221  corrected
# 77           9         DT  0.211878  corrected
# 78           9         LR  0.216752  corrected
# 79           9        SVM  0.215999  corrected
# 80          10         RF  0.064309      input
# 81          10         DT  0.015537      input
# 82          10         LR  0.064309      input
# 83          10        SVM  0.214538      input
# 84          10         RF  0.086575  corrected
# 85          10         DT  0.215176  corrected
# 86          10         LR  0.205042  corrected
# 87          10        SVM  0.208465  corrected
# 88          11         RF  0.064309      input
# 89          11         DT  0.068442      input
# 90          11         LR  0.058059      input
# 91          11        SVM  0.086495      input
# 92          11         RF  0.084718  corrected
# 93          11         DT  0.198094  corrected
# 94          11         LR  0.191552  corrected
# 95          11        SVM  0.209032  corrected
# 96          12         RF  0.142448      input
# 97          12         DT  0.060393      input
# 98          12         LR  0.013652      input
# 99          12        SVM  0.006441      input
# 100         12         RF  0.094047  corrected
# 101         12         DT  0.186828  corrected
# 102         12         LR  0.211010  corrected
# 103         12        SVM  0.233798  corrected
# 104         13         RF  0.064309      input
# 105         13         DT  0.181772      input
# 106         13         LR  0.101740      input
# 107         13        SVM  0.002677      input
# 108         13         RF  0.082936  corrected
# 109         13         DT  0.182743  corrected
# 110         13         LR  0.223629  corrected
# 111         13        SVM  0.222493  corrected
# 112         14         RF  0.064309      input
# 113         14         DT  0.075341      input
# 114         14         LR  0.136586      input
# 115         14        SVM  0.064499      input
# 116         14         RF  0.064108  corrected
# 117         14         DT  0.192070  corrected
# 118         14         LR  0.216463  corrected
# 119         14        SVM  0.213029  corrected
# 120         15         RF  0.058059      input
# 121         15         DT  0.063249      input
# 122         15         LR  0.072132      input
# 123         15        SVM  0.048909      input
# 124         15         RF  0.099907  corrected
# 125         15         DT  0.194271  corrected
# 126         15         LR  0.227897  corrected
# 127         15        SVM  0.227587  corrected
# 128         16         RF  0.053057      input
# 129         16         DT  0.099223      input
# 130         16         LR  0.061026      input
# 131         16        SVM  0.009486      input
# 132         16         RF  0.106969  corrected
# 133         16         DT  0.180418  corrected
# 134         16         LR  0.213543  corrected
# 135         16        SVM  0.188943  corrected
# 136         17         RF  0.152721      input
# 137         17         DT  0.064578      input
# 138         17         LR  0.121599      input
# 139         17        SVM  0.115430      input
# 140         17         RF  0.073309  corrected
# 141         17         DT  0.205904  corrected
# 142         17         LR  0.219796  corrected
# 143         17        SVM  0.232409  corrected
# 144         18         RF  0.058059      input
# 145         18         DT  0.105821      input
# 146         18         LR  0.058059      input
# 147         18        SVM  0.057592      input
# 148         18         RF  0.089366  corrected
# 149         18         DT  0.188209  corrected
# 150         18         LR  0.207347  corrected
# 151         18        SVM  0.209379  corrected
# 152         19         RF  0.064309      input
# 153         19         DT  0.056182      input
# 154         19         LR  0.058059      input
# 155         19        SVM  0.058059      input
# 156         19         RF  0.086755  corrected
# 157         19         DT  0.165509  corrected
# 158         19         LR  0.221039  corrected
# 159         19        SVM  0.208069  corrected
# 160         20         RF  0.117535      input
# 161         20         DT  0.050414      input
# 162         20         LR  0.102016      input
# 163         20        SVM  0.204285      input
# 164         20         RF  0.082709  corrected
# 165         20         DT  0.192091  corrected
# 166         20         LR  0.232354  corrected
# 167         20        SVM  0.231454  corrected
# 168         21         RF  0.067189      input
# 169         21         DT  0.244791      input
# 170         21         LR  0.103835      input
# 171         21        SVM  0.233051      input
# 172         21         RF  0.064499  corrected
# 173         21         DT  0.158781  corrected
# 174         21         LR  0.185580  corrected
# 175         21        SVM  0.193268  corrected
# 176         22         RF  0.064309      input
# 177         22         DT  0.103297      input
# 178         22         LR  0.056638      input
# 179         22        SVM  0.180186      input
# 180         22         RF  0.073339  corrected
# 181         22         DT  0.201554  corrected
# 182         22         LR  0.214601  corrected
# 183         22        SVM  0.206655  corrected
# 184         23         RF  0.064309      input
# 185         23         DT  0.097814      input
# 186         23         LR  0.053057      input
# 187         23        SVM  0.064665      input
# 188         23         RF  0.080733  corrected
# 189         23         DT  0.187242  corrected
# 190         23         LR  0.199416  corrected
# 191         23        SVM  0.199474  corrected
# 192         24         RF  0.068495      input
# 193         24         DT  0.095636      input
# 194         24         LR  0.225452      input
# 195         24        SVM  0.048939      input
# 196         24         RF  0.064001  corrected
# 197         24         DT  0.198418  corrected
# 198         24         LR  0.218432  corrected
# 199         24        SVM  0.222992  corrected
# 200         25         RF  0.058059      input
# 201         25         DT  0.098099      input
# 202         25         LR  0.063050      input
# 203         25        SVM  0.031685      input
# 204         25         RF  0.084662  corrected
# 205         25         DT  0.183858  corrected
# 206         25         LR  0.223954  corrected
# 207         25        SVM  0.207981  corrected
# 208         26         RF  0.098656      input
# 209         26         DT  0.071978      input
# 210         26         LR  0.080585      input
# 211         26        SVM  0.099963      input
# 212         26         RF  0.078035  corrected
# 213         26         DT  0.186130  corrected
# 214         26         LR  0.229052  corrected
# 215         26        SVM  0.217289  corrected
# 216         27         RF  0.064309      input
# 217         27         DT  0.098099      input
# 218         27         LR  0.098191      input
# 219         27        SVM  0.074329      input
# 220         27         RF  0.098926  corrected
# 221         27         DT  0.169912  corrected
# 222         27         LR  0.205973  corrected
# 223         27        SVM  0.198713  corrected
# 224         28         RF  0.053057      input
# 225         28         DT  0.053057      input
# 226         28         LR  0.097325      input
# 227         28        SVM  0.074501      input
# 228         28         RF  0.090172  corrected
# 229         28         DT  0.206442  corrected
# 230         28         LR  0.228745  corrected
# 231         28        SVM  0.229200  corrected
# 232         29         RF  0.097603      input
# 233         29         DT  0.053057      input
# 234         29         LR  0.381231      input
# 235         29        SVM  0.094449      input
# 236         29         RF  0.070375  corrected
# 237         29         DT  0.133617  corrected
# 238         29         LR  0.203806  corrected
# 239         29        SVM  0.188911  corrected

# %%
print(sys_file_names)
print(mthd_file_disk_name)
# Out:
# cell-line+CPTAC
# vae_disc

# %%
ls ../results/r72/

# %%
results_df.to_csv('../results/r72/'+
                  production_date+'/input-'+mthd_file_disk_name+
                  '_clf-eval-n4_x-val=30_'+sys_file_names+'.tsv',
                 sep = '\t')

# %%
sample_count_lbl

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a figure and axis
plt.figure(figsize=(10, 7))

# Plot
sns.boxplot(data=results_df, x='classifier', y='score',
            hue='type', palette='Set2')

# cancer_count = 5
# cancer_count = 5

# Adding title and labels
plt.title('Classification Prediction Performance on Input'+
          ' vs Corrected Data\nTrain on '+mdl_sys_inline+' 85% subsample, '+
          'predict on CPTAC, n cancers = '+str(cancer_count)+
          '\n'+corr_mthd_title+', transcriptomics', fontsize=16)
plt.xlabel('Classifier', fontsize=15)
plt.ylabel('F1 Score', fontsize=15)
plt.legend(title='Data Type', fontsize=12)

plt.annotate(sample_count_lbl+' samples: {}'.format(len(inp_mdl_sys_train_df))+
             '\nCPTAC samples: {}'.format(len(CPTAC_input))+
             '\nLatent dim: '+str(latent_dim)+'\nFeature count: {}'.format(
                 len(X_input.columns)), 
                 # xy=(0.03, 0.85), # Tybalt
                 xy=(0.55, 0.85), # 
                 xycoords='axes fraction', 
                 bbox=dict(boxstyle='round, pad=0.5', fc='white', ec='black'),
                 fontsize=12)

# Display the plot
plt.tight_layout()
plt.savefig('../results/r72/'+
            production_date+'/input-'+mthd_file_disk_name+
            '_clf-eval-n4_x-val=30_'+sys_file_names+'.png',
            dpi = 300)
# plt.show()

# %%
X_input
